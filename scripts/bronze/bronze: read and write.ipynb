# %% [markdown]
# #Reading csv file

# %%
#spark code to read the csv
df=(
  spark.read.option("header","true").option("inferSchema","true").csv("/Volumes/erp/bronze/source_systems/source_crm/cust_info.csv"))
#display the dataframe
display(df)

# %% [markdown]
# #Write csv to bronze layer

# %%
df.write.mode("overwrite").saveAsTable("erp.bronze.crm_cust_info")

# %%
# %sql
select * from erp.bronze.crm_cust_info
